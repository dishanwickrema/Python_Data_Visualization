# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#Reading CSV
Employment = pd.read_csv("../Dataset/Employment_to_Population.csv", encoding="ISO-8859-1")
Employment.head()
# Out:
#        Country Country Code       1991       1992       1993       1994  \
# 0        Aruba          ABW        NaN        NaN        NaN        NaN
# 1  Afghanistan          AFG  61.546001  61.462002  61.276001  61.145000
# 2       Angola          AGO  60.372002  61.653999  61.419998  61.417999
# 3      Albania          ALB  54.845001  54.348999  53.709999  53.183998
# 4      Andorra          AND        NaN        NaN        NaN        NaN
#
#         1995       1996       1997       1998  ...       2009       2010  \
# 0        NaN        NaN        NaN        NaN  ...        NaN        NaN
# 1  61.087002  60.993000  60.902000  60.880001  ...  61.806999  61.851002
# 2  61.344002  62.167000  61.069000  61.858002  ...  69.514999  70.731003
# 3  52.294998  51.536999  52.158001  51.911999  ...  47.077000  46.625999
# 4        NaN        NaN        NaN        NaN  ...        NaN        NaN
#
#         2011       2012       2013       2014       2015       2016  \
# ...

# %%
Employment.set_index('Country', inplace=True)
Employment.head()
# Out:
#             Country Code       1991       1992       1993       1994  \
# Country
# Aruba                ABW        NaN        NaN        NaN        NaN
# Afghanistan          AFG  61.546001  61.462002  61.276001  61.145000
# Angola               AGO  60.372002  61.653999  61.419998  61.417999
# Albania              ALB  54.845001  54.348999  53.709999  53.183998
# Andorra              AND        NaN        NaN        NaN        NaN
#
#                   1995       1996       1997       1998       1999  ...  \
# Country                                                             ...
# Aruba              NaN        NaN        NaN        NaN        NaN  ...
# Afghanistan  61.087002  60.993000  60.902000  60.880001  60.817001  ...
# Angola       61.344002  62.167000  61.069000  61.858002  61.493000  ...
# Albania      52.294998  51.536999  52.158001  51.911999  51.327000  ...
# Andorra            NaN        NaN        NaN        NaN        NaN  ...
#
# ...

# %%
#Counting Rows and Columns
Employment.columns
# Out:
# Index(['Country Code', '1991', '1992', '1993', '1994', '1995', '1996', '1997',
#        '1998', '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006',
#        '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015',
#        '2016', '2017', '2018'],
#       dtype='object')

# %%
# Dropping columns, in order to analyse from 2008 to 2018
Employment.drop(['Country Code','1991', '1992', '1993', '1994', '1995', '1996', '1997', '1998',
       '1999', '2000', '2001', '2002', '2003', '2004', '2005', '2006', '2007'], axis=1, inplace=True)
Employment.head()
# Out:
#                   2008       2009       2010       2011       2012       2013  \
# Country
# Aruba              NaN        NaN        NaN        NaN        NaN        NaN
# Afghanistan  61.960999  61.806999  61.851002  62.280998  62.813999  63.213001
# Angola       68.355003  69.514999  70.731003  72.132004  72.167999  72.098000
# Albania      47.866001  47.077000  46.625999  48.203999  49.759998  45.139999
# Andorra            NaN        NaN        NaN        NaN        NaN        NaN
#
#                   2014       2015       2016       2017       2018
# Country
# Aruba              NaN        NaN        NaN        NaN        NaN
# Afghanistan  63.665001  64.172997  64.511002  64.858002  64.939003
# Angola       72.102997  72.181000  72.142998  72.186996  72.039001
# Albania      44.851002  46.808998  47.724998  48.458000  48.269001
# Andorra            NaN        NaN        NaN        NaN        NaN

# %%
# Filter Data for Canada, China, Philippines and India
Emp_compare= Employment.loc[["Canada", "China", "India", "Philippines"], :]
Emp_compare.head()
# Out:
#                   2008       2009       2010       2011       2012       2013  \
# Country
# Canada       63.084999  61.181000  61.217999  61.387001  61.375999  61.487999
# China        68.572998  68.093002  67.778999  67.599998  67.371002  67.175003
# India        54.518002  53.568001  52.769001  51.816002  50.846001  50.779999
# Philippines  59.595001  59.881001  59.970001  60.661999  60.259998  60.004002
#
#                   2014       2015       2016       2017       2018
# Country
# Canada       61.159000  61.014999  60.813999  61.306999  61.369999
# China        66.953003  66.679001  66.420998  66.164001  65.683998
# India        50.799000  50.756001  50.712002  50.716999  50.601002
# Philippines  60.573002  60.613998  60.518002  58.214001  58.334000

# %%
#Transpose the Data to depict the Graph
Emp_df = Emp_compare.T
Emp_df.head(11)
# Out:
# Country     Canada      China      India  Philippines
# 2008     63.084999  68.572998  54.518002    59.595001
# 2009     61.181000  68.093002  53.568001    59.881001
# 2010     61.217999  67.778999  52.769001    59.970001
# 2011     61.387001  67.599998  51.816002    60.661999
# 2012     61.375999  67.371002  50.846001    60.259998
# 2013     61.487999  67.175003  50.779999    60.004002
# 2014     61.159000  66.953003  50.799000    60.573002
# 2015     61.014999  66.679001  50.756001    60.613998
# 2016     60.813999  66.420998  50.712002    60.518002
# 2017     61.306999  66.164001  50.716999    58.214001
# 2018     61.369999  65.683998  50.601002    58.334000

# %%
Emp_df.describe()
# Out:
# Country     Canada      China      India  Philippines
# count    11.000000  11.000000  11.000000    11.000000
# mean     61.399999  67.135637  51.625637    59.875000
# std       0.590597   0.864463   1.376766     0.863254
# min      60.813999  65.683998  50.601002    58.214001
# 25%      61.170000  66.549999  50.736500    59.738001
# 50%      61.306999  67.175003  50.799000    60.004002
# 75%      61.381500  67.689499  52.292501    60.545502
# max      63.084999  68.572998  54.518002    60.661999

# %%
# Plot the line
plt.figure(figsize=(10,5))
plt.title("Employment to Population from 2008 to 2018")
plt.plot(Emp_df)
plt.xlabel('Years')
plt.ylabel('Employment to Population Rate')
plt.legend(Emp_df, loc = 'best')
plt.show()

# %%
#Higher the Employment rate compared to population better the outcome
